# %% [markdown]
# # TW1
#
# ## Pandas Series and DataFrame
#
# - Practice Pandas Series and DataFrame with examples.

# %% [markdown]
# #### Write your full name.
# Trinh Tran
#
#
#
# #### Submission:
#
# -Start a new Github repository for this course.
#
# -Push the completed code to your Github repository.

# %% [markdown]
# ## Part 0
#
# Practice Pandas Series and DataFrame with the given examples.

# %%
import pandas as pd

# %%
alist = ['Mouse', 'Giraffe', 'Tiger', 'Dog', 'Hippopotamus', 'Moose', 'Bear']
animals = pd.Series(alist)
animals
# Out:
# 0           Mouse
# 1         Giraffe
# 2           Tiger
# 3             Dog
# 4    Hippopotamus
# 5           Moose
# 6            Bear
# dtype: object

# %%
animals[2]
# Out:
# 'Tiger'

# %%
animals.iloc[2]
# Out:
# 'Tiger'

# %%
animals.loc[2]
# Out:
# 'Tiger'

# %%
s1 = pd.Series(alist, index=[0, 1, 2, 3, 4, 5, 6])
s1.iloc[2]
# Out:
# 'Tiger'

# %%
s1.loc[2]
# Out:
# 'Tiger'

# %%
s2 = pd.Series(alist, index=['a', 'b', 'c', 'd', 'e', 'f', 'g'])
s2
# Out:
# a           Mouse
# b         Giraffe
# c           Tiger
# d             Dog
# e    Hippopotamus
# f           Moose
# g            Bear
# dtype: object

# %%
s2['c']
# Out:
# 'Tiger'

# %%
s2.iloc[2]
# Out:
# 'Tiger'

# %%
names = ['Chris', 'Kevin', 'Bob', 'Vinod', 'Daniel', 'Fil', 'Stephanie']
owners = pd.Series(names)
owners
# Out:
# 0        Chris
# 1        Kevin
# 2          Bob
# 3        Vinod
# 4       Daniel
# 5          Fil
# 6    Stephanie
# dtype: object

# %%
frame = {'animals': animals, 'owners': owners}

df = pd.DataFrame(frame)

df
# Out:
#         animals     owners
# 0         Mouse      Chris
# 1       Giraffe      Kevin
# 2         Tiger        Bob
# 3           Dog      Vinod
# 4  Hippopotamus     Daniel
# 5         Moose        Fil
# 6          Bear  Stephanie

# %%
df.columns
# Out:
# Index(['animals', 'owners'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
type(df['animals'])
# Out:
# pandas.core.series.Series

# %%
df.iloc[0]
# Out:
# animals    Mouse
# owners     Chris
# Name: 0, dtype: object

# %%
df.loc[0][1]
# Out:
# C:\Users\Lan Trinh\AppData\Local\Temp\ipykernel_21136\395987507.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[0][1]
# 'Chris'

# %%
df.owners
# Out:
# 0        Chris
# 1        Kevin
# 2          Bob
# 3        Vinod
# 4       Daniel
# 5          Fil
# 6    Stephanie
# Name: owners, dtype: object

# %%
df['owners']
# Out:
# 0        Chris
# 1        Kevin
# 2          Bob
# 3        Vinod
# 4       Daniel
# 5          Fil
# 6    Stephanie
# Name: owners, dtype: object

# %%
# copy an existing DataFrame to create a new dataFrame
copy_df = df.copy()
copy_df
# Out:
#         animals     owners
# 0         Mouse      Chris
# 1       Giraffe      Kevin
# 2         Tiger        Bob
# 3           Dog      Vinod
# 4  Hippopotamus     Daniel
# 5         Moose        Fil
# 6          Bear  Stephanie

# %%
# drop columns

df2 = df.drop(['owners'], axis = 1)

df2
# Out:
#         animals
# 0         Mouse
# 1       Giraffe
# 2         Tiger
# 3           Dog
# 4  Hippopotamus
# 5         Moose
# 6          Bear

# %%
# drop columns

df3 = df.drop(columns = ['owners'])

df3
# Out:
#         animals
# 0         Mouse
# 1       Giraffe
# 2         Tiger
# 3           Dog
# 4  Hippopotamus
# 5         Moose
# 6          Bear

# %%
# drop rows

df4 = df.drop([0,1])
df4
# Out:
#         animals     owners
# 2         Tiger        Bob
# 3           Dog      Vinod
# 4  Hippopotamus     Daniel
# 5         Moose        Fil
# 6          Bear  Stephanie

# %%
midx = pd.MultiIndex(levels=[['lama', 'cow', 'falcon'],
                             ['speed', 'weight']],
                     codes=[[0, 0, 1, 1, 2, 2],
                            [0, 1, 0, 1, 0, 1]])

midx
# Out:
# MultiIndex([(  'lama',  'speed'),
#             (  'lama', 'weight'),
#             (   'cow',  'speed'),
#             (   'cow', 'weight'),
#             ('falcon',  'speed'),
#             ('falcon', 'weight')],
#            )

# %%
df = pd.DataFrame(index=midx, columns=['big', 'small'],
                   data=[[45, 30], [200, 100], [30, 20], [250, 150], [320, 250],[1, 0.8]])

df
# Out:
#                big  small
# lama   speed    45   30.0
#        weight  200  100.0
# cow    speed    30   20.0
#        weight  250  150.0
# falcon speed   320  250.0
#        weight    1    0.8

# %%
df.drop(index='cow', columns='small')
# Out:
#                big
# lama   speed    45
#        weight  200
# falcon speed   320
#        weight    1

# %%
df.drop(index='weight', level=1)
# Out:
#               big  small
# lama   speed   45   30.0
# cow    speed   30   20.0
# falcon speed  320  250.0

# %% [markdown]
# ## Part 1 Task 1
#
# Given the data below, implement each tasks.
#
# <img src="img/df.png" style="height:200px">
#
# (1) Create a DataFrame.
#
# (2) Access the first row data and print it.
#
# (3) Access the first column data (indexed by 'dept') and print it.
#
# (4) Create a new DataFrame by dropping the 2nd column data (indexed by 'floor') from the current DataFrame.

# %% [markdown]
# ### (1) Create a DataFrame

# %%
df = pd.DataFrame(columns=['dept', 'floor'],
                   data=[['CS', 5], ['Bio', 3], ['Chem', 3], ['Phy', 2], ['Eng', 4]])

df
# Out:
#    dept  floor
# 0    CS      5
# 1   Bio      3
# 2  Chem      3
# 3   Phy      2
# 4   Eng      4

# %% [markdown]
# ### (2) Access the first row data and print it

# %%
print(df.iloc[0])
# Out:
# dept     CS
# floor     5
# Name: 0, dtype: object

# %% [markdown]
# ### (3) Access the first column data (indexed by 'dept') and print it

# %%
print(df.dept)
# Out:
# 0      CS
# 1     Bio
# 2    Chem
# 3     Phy
# 4     Eng
# Name: dept, dtype: object

# %% [markdown]
# ### (4) Create a new DataFrame by dropping the 2nd column data (indexed by 'floor') from the current DataFrame

# %%
df2 = df.drop(['floor'], axis = 1)
df2
# Out:
#    dept
# 0    CS
# 1   Bio
# 2  Chem
# 3   Phy
# 4   Eng

# %% [markdown]
# ## Part 1 Task 2
#
# Practice with a data file.
#
# (1) Choose one data file from the data folder in the given TW1 folder.
#
# (2) Read the data into a DataFrame.
#
# (3) Access the rows and columns.
#
# (4) Drop some columns.

# %% [markdown]
# ### (1) Choose one data file from the data folder in the given TW1 folder: cars.csv

# %% [markdown]
# ### (2) Read the data into a DataFrame

# %%
cars_df = pd.read_csv('data/cars.csv')
cars_df.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# 0              2.4               2.1       0     NaN   100         7
# 1              2.6               2.4       0     NaN   117         7
# 2              2.4               2.2       0     NaN   122         4
# 3              2.4               2.1       0     NaN   100         7
# 4              2.6               2.4       0     NaN   117         7

# %% [markdown]
# ### (3) Access the rows and columns

# %%
cars_df.Make[0]
# Out:
# 'MITSUBISHI'

# %%
cars_df.Make.unique()
# Out:
# array(['MITSUBISHI', 'NISSAN', 'FORD', 'SMART', 'TESLA', 'CHEVROLET',
#        'BMW', 'KIA'], dtype=object)

# %%
cars_df.iloc[0]
# Out:
# YEAR                       2012
# Make                 MITSUBISHI
# Model                    i-MiEV
# Size                 SUBCOMPACT
# (kW)                         49
# Unnamed: 5                   A1
# TYPE                          B
# CITY (kWh/100 km)          16.9
# HWY (kWh/100 km)           21.4
# COMB (kWh/100 km)          18.7
# CITY (Le/100 km)            1.9
# HWY (Le/100 km)             2.4
# COMB (Le/100 km)            2.1
# (g/km)                        0
# RATING                      NaN
# (km)                        100
# TIME (h)                      7
# Name: 0, dtype: object

# %%
cars_df.iloc[0, 1]
# Out:
# 'MITSUBISHI'

# %%
cars_df.loc[0:3]
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# 0              2.4               2.1       0     NaN   100         7
# 1              2.6               2.4       0     NaN   117         7
# 2              2.4               2.2       0     NaN   122         4
# 3              2.4               2.1       0     NaN   100         7

# %% [markdown]
# ### (4) Drop some columns

# %%
cars_df = cars_df.drop(['TYPE', 'Size'], axis=1)
cars_df.head()
# Out:
#    YEAR        Make           Model  (kW) Unnamed: 5  CITY (kWh/100 km)  \
# 0  2012  MITSUBISHI          i-MiEV    49         A1               16.9
# 1  2012      NISSAN            LEAF    80         A1               19.3
# 2  2013        FORD  FOCUS ELECTRIC   107         A1               19.0
# 3  2013  MITSUBISHI          i-MiEV    49         A1               16.9
# 4  2013      NISSAN            LEAF    80         A1               19.3
#
#    HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  HWY (Le/100 km)  \
# 0              21.4               18.7               1.9              2.4
# 1              23.0               21.1               2.2              2.6
# 2              21.1               20.0               2.1              2.4
# 3              21.4               18.7               1.9              2.4
# 4              23.0               21.1               2.2              2.6
#
#    COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# 0               2.1       0     NaN   100         7
# 1               2.4       0     NaN   117         7
# 2               2.2       0     NaN   122         4
# 3               2.1       0     NaN   100         7
# 4               2.4       0     NaN   117         7
